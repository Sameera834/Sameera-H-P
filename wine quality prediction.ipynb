# %%
#Importing required packages.
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from feature_engine.outliers import Winsorizer
import feature_engine.transformation as vt

# for one hot encoding with sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

from collections import Counter

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
# %matplotlib inline

# Ignoring Unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
pip install feature_engine
# Out:
# Collecting feature_engine
#   Downloading feature_engine-1.8.2-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from feature_engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from feature_engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from feature_engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from feature_engine) (1.14.1)
# Collecting statsmodels>=0.11.1 (from feature_engine)
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.2.0->feature_engine) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.4.0->feature_engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.4.0->feature_engine) (3.5.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.11.1->feature_engine)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels>=0.11.1->feature_engine) (24.1)
# Requirement already satisfied: six in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Downloading feature_engine-1.8.2-py2.py3-none-any.whl (374 kB)
# Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.9 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.9 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.9 MB 1.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 2.9/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------- -------------------------- 3.4/9.9 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 3.7/9.9 MB 1.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.2/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.8/9.9 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.1/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.3 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels, feature_engine
# Successfully installed feature_engine-1.8.2 patsy-0.5.6 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
plt.figure(1, figsize=(5,5))
df['quality'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
df.quality.value_counts(ascending=False)
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# Function to create a histogram, and a boxplot and scatter plot.
def diagnostic_plots(df, variable,target):
    # The function takes a dataframe (df) and
    # the variable of interest as arguments.

    # Define figure size.
    plt.figure(figsize=(20, 4))

    # histogram
    plt.subplot(1, 4, 1)
    sns.histplot(df[variable], bins=30,color = 'r')
    plt.title('Histogram')


    # scatterplot
    plt.subplot(1, 4, 2)
    plt.scatter(df[variable],df[target],color = 'g')
    plt.title('Scatterplot')
    
    
    # boxplot
    plt.subplot(1, 4, 3)
    sns.boxplot(y=df[variable],color = 'b')
    plt.title('Boxplot')
    
    # barplot
    plt.subplot(1, 4, 4)
    sns.barplot(x = target, y = variable, data = df)   
    plt.title('Barplot')
    
    
    plt.show()

# %%
for variable in df:
    diagnostic_plots(df,variable,'quality')

# %%
corr = df.corr()
plt.figure(figsize=(10, 10))
k = 12 #number of variables for heatmap
cols = corr.nlargest(k, 'quality')['quality'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values,cmap="Blues")
plt.show()

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
def detect_outliers(df,features):
    outlier_indices = []
    
    for c in features:
        # 1st quartile
        Q1 = np.percentile(df[c],25)
        # 3rd quartile
        Q3 = np.percentile(df[c],75)
        # IQR
        IQR = Q3 - Q1
        # Outlier step
        outlier_step = IQR * 1.5
        # detect outlier and their indeces
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        # store indeces
        outlier_indices.extend(outlier_list_col)
    
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 2)
    
    return multiple_outliers

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.iloc[detect_outliers(df,df.columns[:-1])]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 353            13.5             0.530         0.79             4.8      0.120
# 364            12.8             0.615         0.66             5.8      0.083
# 366            12.8             0.615         0.66             5.8      0.083
# 374            14.0             0.410         0.63             3.8      0.089
# 442            15.6             0.685         0.76             3.7      0.100
# 538            12.9             0.350         0.49             5.8      0.066
# 554            15.5             0.645         0.49             4.2      0.095
# 555            15.5             0.645         0.49             4.2      0.095
# 557            15.6             0.645         0.49             4.2      0.095
# 559            13.0             0.470         0.49             4.3      0.085
# 564            13.0             0.470         0.49             4.3      0.085
# 652            15.9             0.360         0.65             7.5      0.096
# 151             9.2             0.520         1.00             3.4      0.610
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 415             8.6             0.725         0.24             6.6      0.117
# 515             8.5             0.655         0.49             6.1      0.122
# 1114            5.0             0.400         0.50             4.3      0.046
# 1244            5.9             0.290         0.25            13.4      0.067
# 1358            7.4             0.640         0.17             5.4      0.168
# 1434           10.2             0.540         0.37            15.4      0.214
# 1435           10.2             0.540         0.37            15.4      0.214
# 1474            9.9             0.500         0.50            13.8      0.205
# 1476            9.9             0.500         0.50            13.8      0.205
# 1558            6.9             0.630         0.33             6.7      0.235
# 614             9.2             0.755         0.18             2.2      0.148
# 695             5.1             0.470         0.02             1.3      0.034
# 1319            9.1             0.760         0.68             1.7      0.414
# 588             5.0             0.420         0.24             2.0      0.060
# 821             4.9             0.420         0.00             2.1      0.048
# 1270            5.0             0.380         0.01             1.6      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 353                  23.0                  77.0  1.00180  3.18       0.77
# 364                   7.0                  42.0  1.00220  3.07       0.73
# 366                   7.0                  42.0  1.00220  3.07       0.73
# 374                   6.0                  47.0  1.00140  3.01       0.81
# 442                   6.0                  43.0  1.00320  2.95       0.68
# 538                   5.0                  35.0  1.00140  3.20       0.66
# 554                  10.0                  23.0  1.00315  2.92       0.74
# 555                  10.0                  23.0  1.00315  2.92       0.74
# 557                  10.0                  23.0  1.00315  2.92       0.74
# 559                   6.0                  47.0  1.00210  3.30       0.68
# 564                   6.0                  47.0  1.00210  3.30       0.68
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 151                  32.0                  69.0  0.99960  2.74       2.00
# 14                   52.0                 145.0  0.99860  3.16       0.88
# 15                   51.0                 148.0  0.99860  3.17       0.93
# 396                  68.0                 124.0  0.99940  3.47       0.53
# 400                  68.0                 124.0  0.99940  3.47       0.53
# 415                  31.0                 134.0  1.00140  3.32       1.07
# 515                  34.0                 151.0  1.00100  3.31       1.14
# 1114                 29.0                  80.0  0.99020  3.49       0.66
# 1244                 72.0                 160.0  0.99721  3.33       0.54
# 1358                 52.0                  98.0  0.99736  3.28       0.50
# 1434                 55.0                  95.0  1.00369  3.18       0.77
# 1435                 55.0                  95.0  1.00369  3.18       0.77
# 1474                 48.0                  82.0  1.00242  3.16       0.75
# 1476                 48.0                  82.0  1.00242  3.16       0.75
# 1558                 66.0                 115.0  0.99787  3.22       0.56
# 614                  10.0                 103.0  0.99690  2.87       1.36
# 695                  18.0                  44.0  0.99210  3.90       0.62
# 1319                 18.0                  64.0  0.99652  2.90       1.33
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 821                  16.0                  42.0  0.99154  3.71       0.74
# 1270                 26.0                  60.0  0.99084  3.70       0.75
#
#       alcohol  quality
# 353      13.0        5
# 364      10.0        7
# 366      10.0        7
# 374      10.8        6
# 442      11.2        7
# 538      12.0        7
# 554      11.1        5
# 555      11.1        5
# 557      11.1        5
# 559      12.7        6
# 564      12.7        6
# 652      14.9        5
# 151       9.4        4
# 14        9.2        5
# 15        9.2        5
# 396       9.9        5
# 400       9.9        5
# 415       9.3        5
# 515       9.3        5
# 1114     13.6        6
# 1244     10.3        6
# 1358      9.5        5
# 1434      9.0        6
# 1435      9.0        6
# 1474      8.8        5
# 1476      8.8        5
# 1558      9.5        5
# 614      10.2        6
# 695      12.8        6
# 1319      9.1        6
# 588      14.0        8
# 821      14.0        7
# 1270     14.0        6

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
windsoriser = Winsorizer(capping_method='iqr', # choose iqr for IQR rule boundaries or gaussian for mean and std
                          tail='both', # cap left, right or both tails 
                          fold=1.5,
                          variables=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                                     'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                                     'pH', 'sulphates'])

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %%
windsoriser.fit(df)
# Out:
# Winsorizer(capping_method='iqr', fold=1.5, tail='both',
#            variables=['fixed acidity', 'volatile acidity', 'citric acid',
#                       'residual sugar', 'chlorides', 'free sulfur dioxide',
#                       'total sulfur dioxide', 'density', 'pH', 'sulphates'])

# %%
df = windsoriser.transform(df)

# %%
diagnostic_plots(df,'fixed acidity','quality')

# %%
cols = ['fixed acidity', 'volatile acidity', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide',
       'sulphates', 'alcohol']

# %%
lt = vt.LogTransformer(variables = cols)

lt.fit(df)
# Out:
# LogTransformer(variables=['fixed acidity', 'volatile acidity', 'residual sugar',
#                           'chlorides', 'free sulfur dioxide',
#                           'total sulfur dioxide', 'sulphates', 'alcohol'])

# %%
df = lt.transform(df)

# %%
#Making binary classificaion for the response variable.
#Dividing wine as good and bad by giving the limit for the quality
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)

# %%
encoder = LabelEncoder()

# %%
df['quality'] = encoder.fit_transform(df['quality'])

# %%
df['quality'].value_counts()
# Out:
# quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       2.001480         -0.356675         0.00        0.641854  -2.577022
# 1       2.054124         -0.127833         0.00        0.955511  -2.322788
# 2       2.054124         -0.274437         0.04        0.832909  -2.385967
# 3       2.415914         -1.272966         0.56        0.641854  -2.590267
# 4       2.001480         -0.356675         0.00        0.641854  -2.577022
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0             2.397895              3.526361   0.9978  3.51  -0.579818
# 1             3.218876              4.204693   0.9968  3.20  -0.385662
# 2             2.708050              3.988984   0.9970  3.26  -0.430783
# 3             2.833213              4.094345   0.9980  3.16  -0.544727
# 4             2.397895              3.526361   0.9978  3.51  -0.579818
#
#     alcohol  quality
# 0  2.240710        0
# 1  2.282382        0
# 2  2.282382        0
# 3  2.282382        0
# 4  2.240710        0

# %%
# let's separate into training and testing set
X_train, X_test, y_train, y_test = train_test_split(df.drop('quality', axis=1),
                                                    df['quality'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1119, 11), (480, 11))

# %%
# set up the scaler
scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
dct = DecisionTreeClassifier(random_state = 42)
svc = SVC(random_state = 42)
rf = RandomForestClassifier(random_state = 42)
logreg = LogisticRegression(random_state = 42)
knn = KNeighborsClassifier()

# %%
# Define the list classifiers
classifiers = [
    ("knn" , knn),
    ("rf" , rf),
    ("logreg" , logreg),
    ("svc", svc),
    ("dct",dct)
]

# %%
# Iterate over the pre-defined list of classifiers
from sklearn.metrics import accuracy_score
for clf_name, clf in classifiers:
    # Fit clf to the training set
    clf.fit(X_train, y_train)
    
    # Predict y_pred
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)

    # Evaluate clf's accuracy on the test set
    print('{:s} score : {:.3f}'.format(clf_name, acc))
# Out:
# knn score : 0.885
# rf score : 0.915
# logreg score : 0.898
# svc score : 0.908
# dct score : 0.900

# %%
param_grid ={
    'n_estimators' : [50,100,200],
    'max_depth': (1,5,10),
    'min_samples_leaf': (1,5,10)
    }

# %%
gridsearch = GridSearchCV(rf, param_grid=param_grid, scoring='accuracy', cv=5,n_jobs=6)

# %%
rf = RandomForestClassifier(max_depth= 10, min_samples_leaf = 1, n_estimators = 100)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10)
